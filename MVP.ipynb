# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("cardiovascular_diseases.csv",sep = ';'  )

# %%
df.head(5)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.tail(5)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %%
df.sample(5)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 42866  61237  14568       1     165    80.0    110     70            1     1
# 31501  44969  21997       1     155    56.0    140     90            1     1
# 2100    2971  22710       2     170    72.0    125     80            1     1
# 11995  17122  20231       1     172    82.0    110     70            2     1
# 67420  96269  22560       1     157    73.0    140   1000            1     1
#
#        smoke  alco  active  cardio
# 42866      0     0       0       0
# 31501      0     0       1       1
# 2100       0     0       1       0
# 11995      0     0       1       0
# 67420      0     1       0       1

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# ## Data Pre-Processing

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
#drop in useful column that contains data it will not be used in data analysis 
df=df.drop('id', axis=1)

# %%
df.head(5)
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
#Calculate the age by year
df['age']=round(df['age']/365.25)

# %%
df.head(5)
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0  50.0       2     168    62.0    110     80            1     1      0     0
# 1  55.0       1     156    85.0    140     90            3     1      0     0
# 2  52.0       1     165    64.0    130     70            3     1      0     0
# 3  48.0       2     169    82.0    150    100            1     1      0     0
# 4  48.0       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
#Use the height and weight to calculate BMI(Body Mass Index)
df['bmi']=round((df['weight']/(df['height']/100)**2), 1)

# %%
df.head(5)
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0  50.0       2     168    62.0    110     80            1     1      0     0
# 1  55.0       1     156    85.0    140     90            3     1      0     0
# 2  52.0       1     165    64.0    130     70            3     1      0     0
# 3  48.0       2     169    82.0    150    100            1     1      0     0
# 4  48.0       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio   bmi
# 0       1       0  22.0
# 1       1       1  34.9
# 2       0       1  23.5
# 3       1       1  28.7
# 4       0       0  23.0

# %%
#Change the value of gender from 1 and 2 to Male and Female :
def gender(gender):
    if gender==1:
        return 'Female'
    else:
        return 'Male'

# %%
df['gender']=df.gender.apply(gender)

# %%
df.head(5)
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0  50.0    Male     168    62.0    110     80            1     1      0     0
# 1  55.0  Female     156    85.0    140     90            3     1      0     0
# 2  52.0  Female     165    64.0    130     70            3     1      0     0
# 3  48.0    Male     169    82.0    150    100            1     1      0     0
# 4  48.0  Female     156    56.0    100     60            1     1      0     0
#
#    active  cardio   bmi
# 0       1       0  22.0
# 1       1       1  34.9
# 2       0       1  23.5
# 3       1       1  28.7
# 4       0       0  23.0

# %%
cholesterol = {
    1: 'normal',
    2: 'above normal',
    3: 'well above normal',
    
}

# %%
df['cholesterol'] = df.cholesterol.map(cholesterol)

# %%
df.head(10)
# Out:
#     age  gender  height  weight  ap_hi  ap_lo        cholesterol  gluc  smoke  \
# 0  50.0    Male     168    62.0    110     80             normal     1      0
# 1  55.0  Female     156    85.0    140     90  well above normal     1      0
# 2  52.0  Female     165    64.0    130     70  well above normal     1      0
# 3  48.0    Male     169    82.0    150    100             normal     1      0
# 4  48.0  Female     156    56.0    100     60             normal     1      0
# 5  60.0  Female     151    67.0    120     80       above normal     2      0
# 6  61.0  Female     157    93.0    130     80  well above normal     1      0
# 7  62.0    Male     178    95.0    130     90  well above normal     3      0
# 8  48.0  Female     158    71.0    110     70             normal     1      0
# 9  54.0  Female     164    68.0    110     60             normal     1      0
#
#    alco  active  cardio   bmi
# 0     0       1       0  22.0
# 1     0       1       1  34.9
# 2     0       0       1  23.5
# 3     0       1       1  28.7
# 4     0       0       0  23.0
# 5     0       0       0  29.4
# 6     0       1       0  37.7
# 7     0       1       1  30.0
# 8     0       1       0  28.4
# 9     0       0       0  25.3

# %%
gluc = {
    1: 'normal',
    2: 'above normal',
    3: 'well above normal',
    
}

# %%
df['gluc'] = df.gluc.map(gluc)

# %%
df.head(20)
# Out:
#      age  gender  height  weight  ap_hi  ap_lo        cholesterol  \
# 0   50.0    Male     168    62.0    110     80             normal
# 1   55.0  Female     156    85.0    140     90  well above normal
# 2   52.0  Female     165    64.0    130     70  well above normal
# 3   48.0    Male     169    82.0    150    100             normal
# 4   48.0  Female     156    56.0    100     60             normal
# 5   60.0  Female     151    67.0    120     80       above normal
# 6   61.0  Female     157    93.0    130     80  well above normal
# 7   62.0    Male     178    95.0    130     90  well above normal
# 8   48.0  Female     158    71.0    110     70             normal
# 9   54.0  Female     164    68.0    110     60             normal
# 10  62.0  Female     169    80.0    120     80             normal
# 11  52.0    Male     173    60.0    120     80             normal
# 12  40.0    Male     165    60.0    120     80             normal
# 13  54.0  Female     158    78.0    110     70             normal
# 14  40.0    Male     181    95.0    130     90             normal
# 15  46.0    Male     172   112.0    120     80             normal
# 16  58.0  Female     170    75.0    130     70             normal
# 17  46.0  Female     158    52.0    110     70             normal
# 18  48.0  Female     154    68.0    100     70             normal
# 19  60.0    Male     162    56.0    120     70             normal
#
#                  gluc  smoke  alco  active  cardio   bmi
# 0              normal      0     0       1       0  22.0
# 1              normal      0     0       1       1  34.9
# 2              normal      0     0       0       1  23.5
# 3              normal      0     0       1       1  28.7
# 4              normal      0     0       0       0  23.0
# 5        above normal      0     0       0       0  29.4
# 6              normal      0     0       1       0  37.7
# 7   well above normal      0     0       1       1  30.0
# 8              normal      0     0       1       0  28.4
# 9              normal      0     0       0       0  25.3
# 10             normal      0     0       1       0  28.0
# 11             normal      0     0       1       0  20.0
# 12             normal      0     0       0       0  22.0
# 13             normal      0     0       1       0  31.2
# 14             normal      1     1       1       0  29.0
# 15             normal      0     0       0       1  37.9
# 16             normal      0     0       0       0  26.0
# 17  well above normal      0     0       1       0  20.8
# 18             normal      0     0       0       0  28.7
# 19             normal      1     0       1       0  21.3

# %%
#Change the value of smoke from 1 and 0 to smoker and non smoker :
smoke = {
    0: 'non smoker',
    1: 'smoker'
    
}

# %%
df['smoke'] = df.smoke.map(smoke)

# %%
df.head(20)
# Out:
#      age  gender  height  weight  ap_hi  ap_lo        cholesterol  \
# 0   50.0    Male     168    62.0    110     80             normal
# 1   55.0  Female     156    85.0    140     90  well above normal
# 2   52.0  Female     165    64.0    130     70  well above normal
# 3   48.0    Male     169    82.0    150    100             normal
# 4   48.0  Female     156    56.0    100     60             normal
# 5   60.0  Female     151    67.0    120     80       above normal
# 6   61.0  Female     157    93.0    130     80  well above normal
# 7   62.0    Male     178    95.0    130     90  well above normal
# 8   48.0  Female     158    71.0    110     70             normal
# 9   54.0  Female     164    68.0    110     60             normal
# 10  62.0  Female     169    80.0    120     80             normal
# 11  52.0    Male     173    60.0    120     80             normal
# 12  40.0    Male     165    60.0    120     80             normal
# 13  54.0  Female     158    78.0    110     70             normal
# 14  40.0    Male     181    95.0    130     90             normal
# 15  46.0    Male     172   112.0    120     80             normal
# 16  58.0  Female     170    75.0    130     70             normal
# 17  46.0  Female     158    52.0    110     70             normal
# 18  48.0  Female     154    68.0    100     70             normal
# 19  60.0    Male     162    56.0    120     70             normal
#
#                  gluc       smoke  alco  active  cardio   bmi
# 0              normal  non smoker     0       1       0  22.0
# 1              normal  non smoker     0       1       1  34.9
# 2              normal  non smoker     0       0       1  23.5
# 3              normal  non smoker     0       1       1  28.7
# 4              normal  non smoker     0       0       0  23.0
# 5        above normal  non smoker     0       0       0  29.4
# 6              normal  non smoker     0       1       0  37.7
# 7   well above normal  non smoker     0       1       1  30.0
# 8              normal  non smoker     0       1       0  28.4
# 9              normal  non smoker     0       0       0  25.3
# 10             normal  non smoker     0       1       0  28.0
# 11             normal  non smoker     0       1       0  20.0
# 12             normal  non smoker     0       0       0  22.0
# 13             normal  non smoker     0       1       0  31.2
# 14             normal      smoker     1       1       0  29.0
# 15             normal  non smoker     0       0       1  37.9
# 16             normal  non smoker     0       0       0  26.0
# 17  well above normal  non smoker     0       1       0  20.8
# 18             normal  non smoker     0       0       0  28.7
# 19             normal      smoker     0       1       0  21.3

# %%
#Change the value of alco from 1 and 0 to drinker and not drinker :
alco = {
    0: 'not drinker',
    1: 'drinker'
    
}

# %%
df['alco'] = df.alco.map(alco)

# %%
df.head(20)
# Out:
#      age  gender  height  weight  ap_hi  ap_lo        cholesterol  \
# 0   50.0    Male     168    62.0    110     80             normal
# 1   55.0  Female     156    85.0    140     90  well above normal
# 2   52.0  Female     165    64.0    130     70  well above normal
# 3   48.0    Male     169    82.0    150    100             normal
# 4   48.0  Female     156    56.0    100     60             normal
# 5   60.0  Female     151    67.0    120     80       above normal
# 6   61.0  Female     157    93.0    130     80  well above normal
# 7   62.0    Male     178    95.0    130     90  well above normal
# 8   48.0  Female     158    71.0    110     70             normal
# 9   54.0  Female     164    68.0    110     60             normal
# 10  62.0  Female     169    80.0    120     80             normal
# 11  52.0    Male     173    60.0    120     80             normal
# 12  40.0    Male     165    60.0    120     80             normal
# 13  54.0  Female     158    78.0    110     70             normal
# 14  40.0    Male     181    95.0    130     90             normal
# 15  46.0    Male     172   112.0    120     80             normal
# 16  58.0  Female     170    75.0    130     70             normal
# 17  46.0  Female     158    52.0    110     70             normal
# 18  48.0  Female     154    68.0    100     70             normal
# 19  60.0    Male     162    56.0    120     70             normal
#
#                  gluc       smoke         alco  active  cardio   bmi
# 0              normal  non smoker  not drinker       1       0  22.0
# 1              normal  non smoker  not drinker       1       1  34.9
# 2              normal  non smoker  not drinker       0       1  23.5
# 3              normal  non smoker  not drinker       1       1  28.7
# 4              normal  non smoker  not drinker       0       0  23.0
# 5        above normal  non smoker  not drinker       0       0  29.4
# 6              normal  non smoker  not drinker       1       0  37.7
# 7   well above normal  non smoker  not drinker       1       1  30.0
# 8              normal  non smoker  not drinker       1       0  28.4
# 9              normal  non smoker  not drinker       0       0  25.3
# 10             normal  non smoker  not drinker       1       0  28.0
# 11             normal  non smoker  not drinker       1       0  20.0
# 12             normal  non smoker  not drinker       0       0  22.0
# 13             normal  non smoker  not drinker       1       0  31.2
# 14             normal      smoker      drinker       1       0  29.0
# 15             normal  non smoker  not drinker       0       1  37.9
# 16             normal  non smoker  not drinker       0       0  26.0
# 17  well above normal  non smoker  not drinker       1       0  20.8
# 18             normal  non smoker  not drinker       0       0  28.7
# 19             normal      smoker  not drinker       1       0  21.3

# %%
#Change the value of active from 1 and 0 to active and not active :
active = {
    0: 'not active',
    1: 'active'
    
}

# %%
df['active'] = df.active.map(active)

# %%
df.head(20)
# Out:
#      age  gender  height  weight  ap_hi  ap_lo        cholesterol  \
# 0   50.0    Male     168    62.0    110     80             normal
# 1   55.0  Female     156    85.0    140     90  well above normal
# 2   52.0  Female     165    64.0    130     70  well above normal
# 3   48.0    Male     169    82.0    150    100             normal
# 4   48.0  Female     156    56.0    100     60             normal
# 5   60.0  Female     151    67.0    120     80       above normal
# 6   61.0  Female     157    93.0    130     80  well above normal
# 7   62.0    Male     178    95.0    130     90  well above normal
# 8   48.0  Female     158    71.0    110     70             normal
# 9   54.0  Female     164    68.0    110     60             normal
# 10  62.0  Female     169    80.0    120     80             normal
# 11  52.0    Male     173    60.0    120     80             normal
# 12  40.0    Male     165    60.0    120     80             normal
# 13  54.0  Female     158    78.0    110     70             normal
# 14  40.0    Male     181    95.0    130     90             normal
# 15  46.0    Male     172   112.0    120     80             normal
# 16  58.0  Female     170    75.0    130     70             normal
# 17  46.0  Female     158    52.0    110     70             normal
# 18  48.0  Female     154    68.0    100     70             normal
# 19  60.0    Male     162    56.0    120     70             normal
#
#                  gluc       smoke         alco      active  cardio   bmi
# 0              normal  non smoker  not drinker      active       0  22.0
# 1              normal  non smoker  not drinker      active       1  34.9
# 2              normal  non smoker  not drinker  not active       1  23.5
# 3              normal  non smoker  not drinker      active       1  28.7
# 4              normal  non smoker  not drinker  not active       0  23.0
# 5        above normal  non smoker  not drinker  not active       0  29.4
# 6              normal  non smoker  not drinker      active       0  37.7
# 7   well above normal  non smoker  not drinker      active       1  30.0
# 8              normal  non smoker  not drinker      active       0  28.4
# 9              normal  non smoker  not drinker  not active       0  25.3
# 10             normal  non smoker  not drinker      active       0  28.0
# 11             normal  non smoker  not drinker      active       0  20.0
# 12             normal  non smoker  not drinker  not active       0  22.0
# 13             normal  non smoker  not drinker      active       0  31.2
# 14             normal      smoker      drinker      active       0  29.0
# 15             normal  non smoker  not drinker  not active       1  37.9
# 16             normal  non smoker  not drinker  not active       0  26.0
# 17  well above normal  non smoker  not drinker      active       0  20.8
# 18             normal  non smoker  not drinker  not active       0  28.7
# 19             normal      smoker  not drinker      active       0  21.3

# %%
#Change the value of cardio from 1 and 0 to Presence and absence :
cardio = {
    0: 'absence',
    1: 'presence'
    
}

# %%
df['cardio'] = df.cardio.map(cardio)

# %%
df.head(20)
# Out:
#      age  gender  height  weight  ap_hi  ap_lo        cholesterol  \
# 0   50.0    Male     168    62.0    110     80             normal
# 1   55.0  Female     156    85.0    140     90  well above normal
# 2   52.0  Female     165    64.0    130     70  well above normal
# 3   48.0    Male     169    82.0    150    100             normal
# 4   48.0  Female     156    56.0    100     60             normal
# 5   60.0  Female     151    67.0    120     80       above normal
# 6   61.0  Female     157    93.0    130     80  well above normal
# 7   62.0    Male     178    95.0    130     90  well above normal
# 8   48.0  Female     158    71.0    110     70             normal
# 9   54.0  Female     164    68.0    110     60             normal
# 10  62.0  Female     169    80.0    120     80             normal
# 11  52.0    Male     173    60.0    120     80             normal
# 12  40.0    Male     165    60.0    120     80             normal
# 13  54.0  Female     158    78.0    110     70             normal
# 14  40.0    Male     181    95.0    130     90             normal
# 15  46.0    Male     172   112.0    120     80             normal
# 16  58.0  Female     170    75.0    130     70             normal
# 17  46.0  Female     158    52.0    110     70             normal
# 18  48.0  Female     154    68.0    100     70             normal
# 19  60.0    Male     162    56.0    120     70             normal
#
#                  gluc       smoke         alco      active    cardio   bmi
# 0              normal  non smoker  not drinker      active   absence  22.0
# 1              normal  non smoker  not drinker      active  presence  34.9
# 2              normal  non smoker  not drinker  not active  presence  23.5
# 3              normal  non smoker  not drinker      active  presence  28.7
# 4              normal  non smoker  not drinker  not active   absence  23.0
# 5        above normal  non smoker  not drinker  not active   absence  29.4
# 6              normal  non smoker  not drinker      active   absence  37.7
# 7   well above normal  non smoker  not drinker      active  presence  30.0
# 8              normal  non smoker  not drinker      active   absence  28.4
# 9              normal  non smoker  not drinker  not active   absence  25.3
# 10             normal  non smoker  not drinker      active   absence  28.0
# 11             normal  non smoker  not drinker      active   absence  20.0
# 12             normal  non smoker  not drinker  not active   absence  22.0
# 13             normal  non smoker  not drinker      active   absence  31.2
# 14             normal      smoker      drinker      active   absence  29.0
# 15             normal  non smoker  not drinker  not active  presence  37.9
# 16             normal  non smoker  not drinker  not active   absence  26.0
# 17  well above normal  non smoker  not drinker      active   absence  20.8
# 18             normal  non smoker  not drinker  not active   absence  28.7
# 19             normal      smoker  not drinker      active   absence  21.3

# %%
#Use the blood pressure categories to change the values of ap_hi and the ap_lo
def blood_pressure_categories(x,y):
    if x<=120 and y<=80:
        return 'Normal'
    elif x<=129 and y<=80:
        return 'Elevated'
    elif x<=139 or y<=89:
        return 'Stage_1'
    elif x<=180 or y<=120:
        return "Stage_2"
    elif x>180 or y>120:
        return 'Stage_3'
    else:
        return None

# %%
df['bp_c']=df.apply(lambda x:blood_pressure_categories(x['ap_hi'],x['ap_lo']),axis=1)

# %%
df_train,df_test=train_test_split(df, test_size=.2, random_state=199)
